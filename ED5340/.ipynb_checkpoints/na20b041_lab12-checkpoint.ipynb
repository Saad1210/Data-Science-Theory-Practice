# %%
# Question 1
import numpy as np
import pandas as pd

def forward(x,w,b): # forward prop
    k=np.dot(np.array(w),np.array(x).T)
    z=np.add(k,np.array(b).T)
    a=1/(1+np.exp(-z))
    return a.T,z

def backprob(x,y,a1,a2,w1,w2,b1,b2,z1):   # back prop
    
    dz2=np.subtract(a2.T,np.array(y))
    dw2=np.dot(dz2,a1)/len(a1)
    db2=np.sum(dz2)/len(a1)
    d1=np.dot(np.array(w2).T,dz2)
    d2=a1.T
    dz1=np.multiply(d1,d2)
    dw1=np.dot(dz1,x)/len(x)
    db1=dz1/len(x)
    return dw1,db1,dw2,db2,dz1

def update(dw1,db1,dw2,db2,w1,b1,w2,b2):  # update steps
    a=0.0005
    w2=w2-a*dw2
    b2=b2-a*db2
    w1=w1-a*dw1
    b1=b1-a*db1.T

    return w1,b1,w2,b2


def Neural(x,y,w1,w2,b1,b2):  # Neural net

    i=0
    si=0.00001
    dz1=1
    while(i<11400):
        i+=1
        a1,z1=forward(x,w1,b1)
        a2,z2=forward(a1,w2,b2)
        dw1,db1,dw2,db2,dz1=backprob(x,y,a1,a2,w1,w2,b1,b2,z1)
        w1,b1,w2,b2=update(dw1,db1,dw2,db2,w1,b1,w2,b2)


    return w1,b1,w2,b2

df=pd.read_csv(r"C:\Users\shiko\Downloads\Logistic_regression_ls.csv")
df=df.to_dict('list')

x1=df['x1']
x2=df['x2']
y=df['label']

X1=[[x1[i],x2[i]] for i in range(int(len(x1)*0.8))]
X2=[[x1[-i],x2[-i]] for i in range(int(len(x1)*0.2))]
y1=[y[i] for i in range(int(len(x1)*0.8))]
y2=[y[-i] for i in range(int(len(x1)*0.2))]

b1=[[1,2,3,3,0,5,8] for i in range(len(X1))]
b2=[5]
w1=[[-1,-1],[2,3],[1,1],[2,1],[0,0],[7,6],[1,1]]
w2=[[0,1,0,1,0,1,0]]

w1,b1,w2,b2=Neural(X1,y1,w1,w2,b1,b2)  #Train


#Test data
b1=[b1[0] for i in range(len(X2))]
a1,z=forward(X2,w1,b1)
a2,z=forward(a1,w2,b2)
p=[]
for i in range(len(a2)):
    if a2[i]>=0.5:
        p.append(1)
    else:
        p.append(0)
tp=fp=tn=fn=0
for i in range(len(p)):
        if p[i]==y2[i] and p[i]==1:
            tp+=1
        elif p[i]==y2[i] and p[i]==1:
            tn+=1
        elif p[i]!=y2[i] and p[i]==1:
            fp+=1
        elif p[i]!=y2[i] and p[i]==0:
            fn+=1

pre=tp/(tp+fp)
rec=tp/(tp+fn)
f1=pre*rec/(pre+rec)
acc=(tp+tn)/(tp+fp+tn+fn)
print(f'After test data analysis the precision is about {pre}\nRecoil is {rec}\nF1 score is {f1}\nAccuracy is {acc} \nAfter 30000 epoches')
print('NOTE : This is not a generic case, only works for the example given in Notes')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19480\1890909375.py in <module>
#      46     return w1,b1,w2,b2
#      47
# ---> 48 df=pd.read_csv(r"C:\Users\shiko\Downloads\Logistic_regression_ls.csv")
#      49 df=df.to_dict('list')
#      50
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\shiko\\Downloads\\Logistic_regression_ls.csv'
